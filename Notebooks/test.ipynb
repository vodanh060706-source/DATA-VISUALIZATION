# %%
import pandas as pd
import numpy as np

# %%
path = "/run/media/a356/DATA/DEV/PYTHON/DATA VISUALIZATION/DATA_processed/Du_lieu_xuat_khau_nong_san.xlsx"
df = pd.read_excel(path, header=0)
df.shape
df.head(5)
# Out:
#    Tên hàng  Tháng 1_Lượng  Tháng 1_Trị giá  Tháng 2_Lượng  Tháng 2_Trị giá  \
# 0  Thủy sản          0.000       485.025840          0.000       423.000000
# 1   Rau quả          0.000       236.000000          0.000       187.000000
# 2  Hạt điều         17.846       163.126135         13.327       121.335873
# 3    Cà phê        184.917       410.455012        167.880       377.679231
# 4       Chè         10.000        13.511635         10.000        14.000000
#
#    Tháng 3_Lượng  Tháng 3_Trị giá  Tháng 4_Lượng  Tháng 4_Trị giá  \
# 0          0.000       600.000000          0.000       636.000000
# 1          0.000       280.000000          0.000       323.000000
# 2         24.121       228.950735         28.277       272.857341
# 3        186.010       420.978874        143.600       324.899949
# 4         10.414        14.452195         10.000        15.735369
#
#    Tháng 5_Lượng  ...  Tháng 8_Trị giá  Tháng 9_Lượng  Tháng 9_Trị giá  \
# ...
