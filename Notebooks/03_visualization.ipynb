# %% [markdown]
# # 03. Visualization
#
# Trực quan hóa các kết quả phân tích dữ liệu xuất khẩu nông sản
# giai đoạn 2017–2025 nhằm làm rõ xu hướng theo thời gian,
# sự khác biệt giữa các mặt hàng và mối quan hệ giữa sản lượng
# và trị giá xuất khẩu.
# # Cấu trúc file 03_visualization.ipynb
#
# 1. Khởi tạo
# 2. Tổng quan xu hướng theo năm
# 3. So sánh theo mặt hàng
# 4. Xu hướng theo tháng
# 5. Mối quan hệ giữa sản lượng và trị giá
# 6. Phân tích tỷ trọng
# 7. Tổng hợp các biểu đồ
